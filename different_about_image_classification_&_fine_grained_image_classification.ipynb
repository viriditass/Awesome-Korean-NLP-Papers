# %% [markdown]
# <a href="https://colab.research.google.com/github/viriditass/Awesome-Korean-NLP-Papers/blob/master/different_about_image_classification_%26_fine_grained_image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **image classification & fine-grained image classification**

# %% [markdown]
# **image classification**은 이미지가 개에 관한 것인지, 고양이에 관한 것인지, 사람에 관한 것인지, 자동차에 관한 것인지 분류하는 컴퓨터 비전 과제다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 하지만 **fine-grained image classification**은 무엇일까? 새의 종, 꽃의 종, 동물의 종 또는 자동차의 모델 같이 구분하기 어려운 클래스들을 분류하는 과제다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 참고로 image classification의 대표 데이터셋이 **ImageNet**이라면, fine-grained image classfication에 자주 사용되는 데이터셋에는 **CUB-200-2011**, **Stanford Cars**, **Stanford Dogs** 등이 있다.
